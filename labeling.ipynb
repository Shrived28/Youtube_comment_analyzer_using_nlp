# %%
import numpy as np
import pandas as pd

# %%
import re
import pandas as pd
from transformers import pipeline
from tqdm import tqdm

# %%
df1 = pd.read_csv("-2RAq5o5pwc_user_comments.csv")
df2 = pd.read_csv("3y5A4paFOb4_user_comments.csv")
df3 = pd.read_csv("73_1biulkYk_user_comments.csv")
df4 = pd.read_csv("hkb8oCMrxDg_user_comments.csv")
df5 = pd.read_csv("lC9emrW0F2o_user_comments.csv")
df6 = pd.read_csv("OCvsEfuTA_8_user_comments.csv")
df7 = pd.read_csv("oeCytho8wq4_user_comments.csv")
df8 = pd.read_csv("YbJOTdZBX1g_user_comments.csv")
df9 = pd.read_csv("YR12Z8f1Dh8_user_comments.csv")
df  = pd.DataFrame()

# %%
df['comments']  = pd.concat([df1['comment'], df2['comment'],df3['comment'], df4['comment'],df5['comment'], df6['comment'],df7['comment'], df8['comment']], axis=0,names=['comments'])

# %%
df.describe()
# Out:
#                                                  comments
# count                                               33954
# unique                                              27595
# top     This video randomly popped up and I m glad it did
# freq                                                  269

# %%
df
# Out:
#                                               comments
# 0                                              Talha ❤
# 1                     Sanny is the owner of this song😂
# 2                                 Anyone 1 June 2025 😂
# 3                                   Art has no borders
# 4                               Mera khel khatam h🤣🤣🥀🥀
# ..                                                 ...
# 715  I have no nostalgia for this and I still hate it.
# 716       Ngl, ninja being the bus driver  kinda slaps
# 717                                       2025 here? 🎉
# 718                                       20m dislikes
# 719                              20mil dislikes sheesh
#
# [33966 rows x 1 columns]

# %%
classifier = pipeline("sentiment-analysis", model="siebert/sentiment-roberta-large-english")
# Out:
# Device set to use cuda:0

# %%
labels = []
for comment in df['comments']:
    try:
        labels.append(classifier(comment)[0]['label'])
    except:
        labels.append(None)
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Token indices sequence length is longer than the specified maximum sequence length for this model (875 > 512). Running this sequence through the model will result in indexing errors

# %%
labels
# Out:
# ['POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'POSITIVE',
# ...

# %%
df['labels'] = labels

# %%
df.isna().sum()
# Out:
# comments    12
# labels      54
# dtype: int64

# %%
df['labels'].value_counts()
# Out:
# labels
# POSITIVE    23634
# NEGATIVE    10278
# Name: count, dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.to_csv("cleaned_labeled_data.csv",index=False)

# %%
df.isna().sum()
# Out:
# comments    0
# labels      0
# dtype: int64

# %%
# Out:
#                                               comments    labels
# 0                                              Talha ❤  POSITIVE
# 1                     Sanny is the owner of this song😂  POSITIVE
# 2                                 Anyone 1 June 2025 😂  POSITIVE
# 3                                   Art has no borders  POSITIVE
# 4                               Mera khel khatam h🤣🤣🥀🥀  POSITIVE
# ..                                                 ...       ...
# 715  I have no nostalgia for this and I still hate it.  NEGATIVE
# 716       Ngl, ninja being the bus driver  kinda slaps  NEGATIVE
# 717                                       2025 here? 🎉  POSITIVE
# 718                                       20m dislikes  NEGATIVE
# 719                              20mil dislikes sheesh  NEGATIVE
#
# [33912 rows x 2 columns]
